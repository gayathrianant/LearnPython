# %%
x=8
y=6
z=4
x+y-z
print(x+y-z)
print(x**5+y**(-3))
print(y%z)
print((y+x)%z)
# Out:
# 10
# 32768.00462962963
# 2
# 2

# %%
x='Devu'
y=x
print(type(x))
print(y)
print(x,y)
z =x+y
print(z)
# Out:
# <class 'str'>
# Devu
# Devu Devu
# DevuDevu

# %%
x = [1,2,3,4,5,6,7,8, -1, 100, 20, 'Devu']
print(x)
print('Devu' in x)
print('Devasena' in x)
z = [2*i for i in x]
print(z)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, -1, 100, 20, 'Devu']
# True
# False
# [2, 4, 6, 8, 10, 12, 14, 16, -2, 200, 40, 'DevuDevu']

# %%
x = range(0,1000,5)
y = [i/1000 for i in x]
z = [(1-k**2)**0.5 for k in y]
t = [(y[i],z[i]) for i in range(len(y))]
print(t)
print(type(y))
print(type(z))
print(type(t))
# Out:
# [(0.0, 1.0), (0.005, 0.999987499921874), (0.01, 0.9999499987499375), (0.015, 0.9998874936711629), (0.02, 0.999799979995999), (0.025, 0.9996874511566103), (0.03, 0.9995498987044118), (0.035, 0.9993873123068954), (0.04, 0.9991996797437437), (0.045, 0.9989869869022319), (0.05, 0.998749217771909), (0.055, 0.9984863544385572), (0.06, 0.9981983770774224), (0.065, 0.9978852639457103), (0.07, 0.9975469913743412), (0.075, 0.9971835337589565), (0.08, 0.996794863550169), (0.085, 0.9963809512430474), (0.09, 0.995941765365827), (0.095, 0.9954772724678349), (0.1, 0.99498743710662), (0.105, 0.9944722218342753), (0.11, 0.9939315871829408), (0.115, 0.9933654916494734), (0.12, 0.9927738916792685), (0.125, 0.9921567416492215), (0.13, 0.9915139938498094), (0.135, 0.9908455984662797), (0.14, 0.9901515035589251), (0.145, 0.9894316550424289), (0.15, 0.9886859966642595), (0.155, 0.9879144699820932), (0.16, 0.9871170143402453), (0.165, 0.9862935668450848), (0.17, 0.9854440623394105), (0.175, 0.98456843337576
# ...

# %%
x = (1,2,3,5)
print(type(x))
y = (x,1)
print(y)
# Out:
# <class 'tuple'>
# ((1, 2, 3, 5), 1)

# %%
123
# Out:
# 123

# %%
r=33
t=[(k, (k*(k+1))/2) for k in range(1,60)]
print(t)
# Out:
# [(1, 1.0), (2, 3.0), (3, 6.0), (4, 10.0), (5, 15.0), (6, 21.0), (7, 28.0), (8, 36.0), (9, 45.0), (10, 55.0), (11, 66.0), (12, 78.0), (13, 91.0), (14, 105.0), (15, 120.0), (16, 136.0), (17, 153.0), (18, 171.0), (19, 190.0), (20, 210.0), (21, 231.0), (22, 253.0), (23, 276.0), (24, 300.0), (25, 325.0), (26, 351.0), (27, 378.0), (28, 406.0), (29, 435.0), (30, 465.0), (31, 496.0), (32, 528.0), (33, 561.0), (34, 595.0), (35, 630.0), (36, 666.0), (37, 703.0), (38, 741.0), (39, 780.0), (40, 820.0), (41, 861.0), (42, 903.0), (43, 946.0), (44, 990.0), (45, 1035.0), (46, 1081.0), (47, 1128.0), (48, 1176.0), (49, 1225.0), (50, 1275.0), (51, 1326.0), (52, 1378.0), (53, 1431.0), (54, 1485.0), (55, 1540.0), (56, 1596.0), (57, 1653.0), (58, 1711.0), (59, 1770.0)]

# %%
for i in range(1,101) :
    if (i%2 == 0) :
        print(i)
    else :
        print('Odd')
print('Thats all')
# Out:
# Odd
# 2
# Odd
# 4
# Odd
# 6
# Odd
# 8
# Odd
# 10
# Odd
# 12
# Odd
# 14
# Odd
# 16
# Odd
# 18
# Odd
# 20
# Odd
# 22
# Odd
# 24
# Odd
# 26
# Odd
# 28
# Odd
# 30
# Odd
# 32
# Odd
# 34
# Odd
# 36
# Odd
# 38
# Odd
# 40
# Odd
# 42
# Odd
# 44
# Odd
# 46
# Odd
# 48
# Odd
# 50
# Odd
# 52
# Odd
# 54
# Odd
# 56
# Odd
# 58
# Odd
# 60
# Odd
# 62
# Odd
# 64
# Odd
# 66
# Odd
# 68
# Odd
# 70
# Odd
# 72
# Odd
# 74
# Odd
# 76
# Odd
# 78
# Odd
# 80
# Odd
# 82
# Odd
# 84
# Odd
# 86
# Odd
# 88
# Odd
# 90
# Odd
# 92
# Odd
# 94
# Odd
# 96
# Odd
# 98
# Odd
# 100
# Thats all

# %%
for i in range(1,101) :
    if (i > 90) :
        print(i)
print('Thats all')
# Out:
# 91
# 92
# 93
# 94
# 95
# 96
# 97
# 98
# 99
# 100
# Thats all

# %%
x = ['Santhosh', 'Akila', 'Debu', 'Gayu']
y = ['Debu', 'Aaradhya', 'Vidyut','abc']
print('In my family')
for i in y :
    if i in x :
        print(i)
# Out:
# In my family
# Debu
